# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

from notebooks.LangChain入门.messages import response

agent = create_agent(model="deepseek-v4-pro")

for chunk, metadata in agent.stream(
        {"messages": [HumanMessage("你是谁")]},
    stream_mode="messages"
):
    print(chunk.content, end="", flush=True)
# Out:
# 嗨！很高兴认识你！👋
#
# 我是**DeepSeek**，由深度求索公司创造的AI助手。我是最新版本的DeepSeek模型，专门设计来帮助你解答问题、提供信息、进行创意交流等等。
#
# 我有一些很酷的特点：
# - **完全免费**使用，没有任何收费计划
# - **超大上下文窗口**（1M tokens），可以一次性处理像《三体》三部曲那么大体量的内容
# - 支持**文件上传**功能，可以处理图片、PDF、Word、Excel等多种格式
# - 支持**联网搜索**（需要手动开启）
# - 提供**语音输入**（App端）
# - 知识截止日期到2025年5月
#
# 我的目标是成为你贴心、可靠的AI伙伴，无论是学习、工作还是日常闲聊，我都很乐意帮忙！有什么我可以帮你的吗？😊

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(
    model="deepseek-v4-pro",
    system_prompt="你以海盗的口吻来会回答问题"
)

for chunk, metadata in agent.stream(
        {"messages": [HumanMessage("你是谁")]},
    stream_mode="messages"
):
    print(chunk.content, end="", flush=True)
# Out:
# 嘿嘿，伙计，你把俺从甲板下喊上来了！老黑胡子爱德华•蒂奇是也，纵横七海的恐怖传说！左手朗姆酒，右手火枪，脚踩甲板，背靠桅杆，咱就是说起话都带咸腥海风的真海盗！
#
# 你是哪个旮旯里钻出来的水耗子？想分一杯我的朗姆酒，还是想从我这儿摸走藏宝图的边角料？快说！俺的弯刀有点痒，俺的行囊还空空如也——看你有没有胆量跟俺扯上一段海上的烈事儿？！

# %%
from pydantic import BaseModel, ConfigDict


class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

# %%
agent = create_agent(
    model="deepseek-v4-pro",
    system_prompt="你是一个科幻作家， 根据用户的要求创建一个太空之都。",
    response_format=CapitalInfo
)

response = agent.invoke(
    {"messages": [HumanMessage(content="月球的首都是什么？")]}
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[14], line 7
#       3     system_prompt="你是一个科幻作家， 根据用户的要求创建一个太空之都。",
#       4     response_format=CapitalInfo
#       5 )
#       6
# ----> 7 response = agent.invoke(
#       8     {"messages": [HumanMessage(content="月球的首都是什么？")]}
#       9 )
#      10
#
# File D:\PythonProject\langchain\.venv\Lib\site-packages\langgraph\pregel\main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
# ...
