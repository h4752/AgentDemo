# %%
from openai import OpenAI
import os

DEEPSEEK_API_KEY = os.environ.get("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.environ.get("DEEPSEEK_BASE_URL")

# 创建 OpenAI 客户端
client = OpenAI(
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

# %%
response = client.chat.completions.create(
    model = "deepseek-v4-pro",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助手。"},
        {"role": "user", "content": "你好， 你是谁？"}
    ],
    stream=False
)

# %%
print(response.model_dump_json())
# Out:
# {"id":"1171c2fc-1bdc-4bd5-88a5-907480ae8af2","choices":[{"finish_reason":"stop","index":0,"logprobs":null,"message":{"content":"你好呀！👋\n\n我是 **DeepSeek**，由深度求索公司创造的AI助手。很高兴认识你！\n\n我可以帮你做很多事情：\n- 回答各种问题，从日常咨询到专业知识\n- 写作、翻译、创意策划\n- 编程和技术支持\n- 分析文档、处理信息\n- 聊天陪伴，倾听你的想法\n\n而且我是**完全免费**的！无论你是用网页版还是App，都可以随时找我帮忙。如果需要处理复杂问题，还可以上传文件让我帮你分析。\n\n有什么我可以帮你的吗？随便聊聊也可以哦！😊","refusal":null,"role":"assistant","annotations":null,"audio":null,"function_call":null,"tool_calls":null,"reasoning_content":"嗯，用户用中文打招呼，询问我是谁。\n\n这是一个非常简单的自我介绍问题。我需要明确告知自己的身份和基本功能。\n\n可以用友好、热情的语气回复，先问候回去，然后说明我是谁、由谁创造、能做什么，最后以开放性问题结束，引导进一步对话。"}}],"created":1782799399,"model":"deepseek-v4-pro","object":"chat.completion","moderation":null,"service_tier":null,"system_fingerprint":"fp_9954b31ca7_prod0820_fp8_kvcache_20260402","usage":{"completion_tokens":181,"prompt_tokens":15,"total_tokens":196,"completion_tokens_details":{"accepted_prediction_tokens":null,"audio_tokens":null,"reasoning_tokens":59,"rejected_prediction_tokens":null},"prompt_tokens_details":{"audio_tokens":null,"cached_tokens":0},"prompt_cache_hit_tokens":0,"prompt_cache_miss_tokens":15}}

# %%
print(response.choices[0].message.content)
# Out:
# 你好呀！👋
#
# 我是 **DeepSeek**，由深度求索公司创造的AI助手。很高兴认识你！
#
# 我可以帮你做很多事情：
# - 回答各种问题，从日常咨询到专业知识
# - 写作、翻译、创意策划
# - 编程和技术支持
# - 分析文档、处理信息
# - 聊天陪伴，倾听你的想法
#
# 而且我是**完全免费**的！无论你是用网页版还是App，都可以随时找我帮忙。如果需要处理复杂问题，还可以上传文件让我帮你分析。
#
# 有什么我可以帮你的吗？随便聊聊也可以哦！😊
